# %%
import os
import numpy as np
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

# %%
# Define dataset path
dataset_path = r"C:\Users\ahmed\OneDrive\Desktop\Files\tasks\Type\Wound_dataset copy"

# %%
# Preprocess image
def preprocess_image(img):
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (299, 299))  # Resize to 299x299
    img = img.astype('float32')
    img = preprocess_input(img)  # Preprocess for ResNet50
    return img

# %%
# Load and preprocess data
def load_data(data_path):
    data = []
    labels = []
    for folder in os.listdir(data_path):
        folder_path = os.path.join(data_path, folder)
        if os.path.isdir(folder_path):  # Ensure it's a directory
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                img = cv2.imread(file_path)
                if img is not None:  # Check if the image was loaded successfully
                    img = preprocess_image(img)  # Apply preprocessing to each image
                    data.append(img)
                    labels.append(folder)
    return np.array(data), np.array(labels)

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input  # Import preprocess_input
# Load all data
X, y = load_data(dataset_path)

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded, num_classes=len(label_encoder.classes_))

# Split data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
# Print shapes
print("Training data shape:", X_train.shape)
print("Validation data shape:", X_val.shape)
print("Training labels shape:", y_train.shape)
print("Validation labels shape:", y_val.shape)
# Out:
# Training data shape: (2352, 299, 299, 3)
# Validation data shape: (588, 299, 299, 3)
# Training labels shape: (2352, 10)
# Validation labels shape: (588, 10)

# %%
# Data Augmentation to reduce overfitting
datagen = ImageDataGenerator(
    rotation_range=30,  # Randomly rotate images by 30 degrees
    width_shift_range=0.2,  # Randomly shift images horizontally by 20%
    height_shift_range=0.2,  # Randomly shift images vertically by 20%
    shear_range=0.2,  # Apply shear transformations
    zoom_range=0.3,  # Randomly zoom in/out by 30%
    brightness_range=[0.7, 1.3],  # Randomly adjust brightness
    horizontal_flip=True,  # Randomly flip images horizontally
    fill_mode='nearest'  # Fill missing pixels with the nearest value
)
datagen.fit(X_train)

# %%
# Build the model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
for layer in base_model.layers[:-10]:  # Fine-tune more layers
    layer.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dense(512, activation='relu', kernel_regularizer='l2'),  # Add L2 regularization
    Dropout(0.5),  # Add Dropout to reduce overfitting
    Dense(len(label_encoder.classes_), activation='softmax')  # Match number of classes
])

# Convert one-hot encoded labels back to integer labels
y_train_int = np.argmax(y_train, axis=1)

# %%
# Compute class weights to handle class imbalance
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_int),  # Unique classes in the training set
    y=y_train_int  # Integer training labels
)
class_weights_dict = dict(enumerate(class_weights))  # Convert to dictionary

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Callbacks
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)  
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)  

# Train the model with data augmentation
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),  # Use augmented data
    validation_data=(X_val, y_val),
    epochs=50,
    class_weight=class_weights_dict,
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# Epoch 1/50
# 74/74 [==============================] - 372s 5s/step - loss: 10.0690 - accuracy: 0.3784 - val_loss: 9.1670 - val_accuracy: 0.6088 - lr: 1.0000e-04
# Epoch 2/50
# 74/74 [==============================] - 363s 5s/step - loss: 8.8530 - accuracy: 0.6293 - val_loss: 8.4640 - val_accuracy: 0.7857 - lr: 1.0000e-04
# Epoch 3/50
# 74/74 [==============================] - 362s 5s/step - loss: 8.2124 - accuracy: 0.7509 - val_loss: 8.0759 - val_accuracy: 0.8197 - lr: 1.0000e-04
# Epoch 4/50
# 74/74 [==============================] - 362s 5s/step - loss: 7.8189 - accuracy: 0.7929 - val_loss: 7.7041 - val_accuracy: 0.8452 - lr: 1.0000e-04
# Epoch 5/50
# 74/74 [==============================] - 362s 5s/step - loss: 7.4574 - accuracy: 0.8121 - val_loss: 7.3662 - val_accuracy: 0.8520 - lr: 1.0000e-04
# Epoch 6/50
# 74/74 [==============================] - 366s 5s/step - loss: 7.1080 - accuracy: 0.8312 - val_loss: 7.0111 - val_accuracy: 0.8827 - lr: 1.0000e-04
# Epoch 7/50
# 74/74 [==============================] - 377s 5s/step - loss: 6.7086 - accuracy: 0.8827 - val_loss: 6.6745 - val_accuracy: 0.8912 - lr: 1.0000e-04
# Epoch 8/50
# 74/74 [==============================] - 363s 5s/step - loss: 6.4110 - accuracy: 0.8780 - val_loss: 6.3634 - val_accuracy: 0.8895 - lr: 1.0000e-04
# Epoch 9/50
# 74/74 [==============================] - 366s 5s/step - loss: 6.0660 - accuracy: 0.8963 - val_loss: 6.0134 - val_accuracy: 0.9099 - lr: 1.0000e-04
# Epoch 10/50
# 74/74 [==============================] - 368s 5s/step - loss: 5.7307 - accuracy: 0.9167 - val_loss: 5.6987 - val_accuracy: 0.9269 - lr: 1.0000e-04
# Epoch 11/50
# 74/74 [==============================] - 365s 5s/step - loss: 5.4022 - accuracy: 0.9230 - val_loss: 5.4233 - val_accuracy: 0.9184 - lr: 1.0000e-04
# Epoch 12/50
# 74/74 [==============================] - 365s 5s/step - loss: 5.1070 - accuracy: 0.9324 - val_loss: 5.1167 - val_accuracy: 0.9201 - lr: 1.0000e-04
# Epoch 13/50
# 74/74 [==============================] - 368s 5s/step - loss: 4.8089 - accuracy: 0.9354 - val_loss: 4.7922 - val_accuracy: 0.9286 - lr: 1.0000e-04
# Epoch 14/50
# 74/74 [==============================] - 366s 5s/step - loss: 4.5085 - accuracy: 0.9409 - val_loss: 4.5152 - val_accuracy: 0.9303 - lr: 1.0000e-04
# Epoch 15/50
# 74/74 [==============================] - 367s 5s/step - loss: 4.2230 - accuracy: 0.9520 - val_loss: 4.2264 - val_accuracy: 0.9388 - lr: 1.0000e-04
# Epoch 16/50
# 74/74 [==============================] - 368s 5s/step - loss: 3.9429 - accuracy: 0.9511 - val_loss: 3.9540 - val_accuracy: 0.9507 - lr: 1.0000e-04
# Epoch 17/50
# 74/74 [==============================] - 372s 5s/step - loss: 3.6765 - accuracy: 0.9588 - val_loss: 3.7129 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 18/50
# 74/74 [==============================] - 371s 5s/step - loss: 3.4124 - accuracy: 0.9660 - val_loss: 3.4438 - val_accuracy: 0.9422 - lr: 1.0000e-04
# Epoch 19/50
# 74/74 [==============================] - 369s 5s/step - loss: 3.1686 - accuracy: 0.9724 - val_loss: 3.2486 - val_accuracy: 0.9371 - lr: 1.0000e-04
# Epoch 20/50
# 74/74 [==============================] - 365s 5s/step - loss: 2.9374 - accuracy: 0.9711 - val_loss: 2.9948 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 21/50
# 74/74 [==============================] - 366s 5s/step - loss: 2.7284 - accuracy: 0.9634 - val_loss: 2.7708 - val_accuracy: 0.9524 - lr: 1.0000e-04
# Epoch 22/50
# 74/74 [==============================] - 365s 5s/step - loss: 2.5208 - accuracy: 0.9715 - val_loss: 2.5587 - val_accuracy: 0.9507 - lr: 1.0000e-04
# Epoch 23/50
# 74/74 [==============================] - 364s 5s/step - loss: 2.3224 - accuracy: 0.9715 - val_loss: 2.3583 - val_accuracy: 0.9507 - lr: 1.0000e-04
# Epoch 24/50
# 74/74 [==============================] - 364s 5s/step - loss: 2.1177 - accuracy: 0.9817 - val_loss: 2.1904 - val_accuracy: 0.9541 - lr: 1.0000e-04
# Epoch 25/50
# 74/74 [==============================] - 365s 5s/step - loss: 1.9406 - accuracy: 0.9796 - val_loss: 2.0187 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 26/50
# 74/74 [==============================] - 369s 5s/step - loss: 1.7830 - accuracy: 0.9809 - val_loss: 1.8838 - val_accuracy: 0.9473 - lr: 1.0000e-04
# Epoch 27/50
# 74/74 [==============================] - 367s 5s/step - loss: 1.6344 - accuracy: 0.9809 - val_loss: 1.7043 - val_accuracy: 0.9558 - lr: 1.0000e-04
# Epoch 28/50
# 74/74 [==============================] - 376s 5s/step - loss: 1.4860 - accuracy: 0.9817 - val_loss: 1.5473 - val_accuracy: 0.9507 - lr: 1.0000e-04
# Epoch 29/50
# 74/74 [==============================] - 371s 5s/step - loss: 1.3451 - accuracy: 0.9821 - val_loss: 1.4105 - val_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 30/50
# 74/74 [==============================] - 366s 5s/step - loss: 1.2197 - accuracy: 0.9830 - val_loss: 1.3220 - val_accuracy: 0.9473 - lr: 1.0000e-04
# Epoch 31/50
# 74/74 [==============================] - 366s 5s/step - loss: 1.1170 - accuracy: 0.9792 - val_loss: 1.2314 - val_accuracy: 0.9524 - lr: 1.0000e-04
# Epoch 32/50
# 74/74 [==============================] - 364s 5s/step - loss: 1.0112 - accuracy: 0.9826 - val_loss: 1.1246 - val_accuracy: 0.9558 - lr: 1.0000e-04
# Epoch 33/50
# 74/74 [==============================] - 364s 5s/step - loss: 0.9188 - accuracy: 0.9834 - val_loss: 1.0222 - val_accuracy: 0.9558 - lr: 1.0000e-04
# Epoch 34/50
# 74/74 [==============================] - 372s 5s/step - loss: 0.8356 - accuracy: 0.9826 - val_loss: 0.9203 - val_accuracy: 0.9473 - lr: 1.0000e-04
# Epoch 35/50
# 74/74 [==============================] - 379s 5s/step - loss: 0.7544 - accuracy: 0.9809 - val_loss: 0.8702 - val_accuracy: 0.9405 - lr: 1.0000e-04
# Epoch 36/50
# 74/74 [==============================] - 375s 5s/step - loss: 0.6748 - accuracy: 0.9868 - val_loss: 0.8268 - val_accuracy: 0.9388 - lr: 1.0000e-04
# Epoch 37/50
# 74/74 [==============================] - 367s 5s/step - loss: 0.6121 - accuracy: 0.9830 - val_loss: 0.7066 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 38/50
# 74/74 [==============================] - 368s 5s/step - loss: 0.5574 - accuracy: 0.9894 - val_loss: 0.6672 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 39/50
# 74/74 [==============================] - 371s 5s/step - loss: 0.5025 - accuracy: 0.9847 - val_loss: 0.6668 - val_accuracy: 0.9405 - lr: 1.0000e-04
# Epoch 40/50
# 74/74 [==============================] - 365s 5s/step - loss: 0.4468 - accuracy: 0.9877 - val_loss: 0.5849 - val_accuracy: 0.9456 - lr: 1.0000e-04
# Epoch 41/50
# 74/74 [==============================] - 364s 5s/step - loss: 0.4091 - accuracy: 0.9881 - val_loss: 0.5499 - val_accuracy: 0.9456 - lr: 1.0000e-04
# Epoch 42/50
# 74/74 [==============================] - 363s 5s/step - loss: 0.3627 - accuracy: 0.9877 - val_loss: 0.4917 - val_accuracy: 0.9541 - lr: 1.0000e-04
# Epoch 43/50
# 74/74 [==============================] - 366s 5s/step - loss: 0.3402 - accuracy: 0.9843 - val_loss: 0.4712 - val_accuracy: 0.9524 - lr: 1.0000e-04
# Epoch 44/50
# 74/74 [==============================] - 382s 5s/step - loss: 0.3156 - accuracy: 0.9821 - val_loss: 0.4442 - val_accuracy: 0.9558 - lr: 1.0000e-04
# Epoch 45/50
# 74/74 [==============================] - 372s 5s/step - loss: 0.2809 - accuracy: 0.9855 - val_loss: 0.4394 - val_accuracy: 0.9422 - lr: 1.0000e-04
# Epoch 46/50
# 74/74 [==============================] - 367s 5s/step - loss: 0.2510 - accuracy: 0.9894 - val_loss: 0.4082 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 47/50
# 74/74 [==============================] - 364s 5s/step - loss: 0.2282 - accuracy: 0.9877 - val_loss: 0.3459 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 48/50
# 74/74 [==============================] - 364s 5s/step - loss: 0.2293 - accuracy: 0.9834 - val_loss: 0.4307 - val_accuracy: 0.9286 - lr: 1.0000e-04
# Epoch 49/50
# 74/74 [==============================] - 370s 5s/step - loss: 0.2061 - accuracy: 0.9847 - val_loss: 0.4167 - val_accuracy: 0.9405 - lr: 1.0000e-04
# Epoch 50/50
# 74/74 [==============================] - 371s 5s/step - loss: 0.1881 - accuracy: 0.9860 - val_loss: 0.3804 - val_accuracy: 0.9405 - lr: 1.0000e-04

# %%
# Plot training and validation loss and accuracy
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='Training Loss', marker='o', color='blue')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, label='Training Accuracy', marker='o', color='blue')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', marker='o', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predict on the validation set
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_val, axis=1)

# Print classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# 19/19 [==============================] - 65s 3s/step
#                  precision    recall  f1-score   support
#
#       Abrasions       1.00      0.93      0.97        30
#         Bruises       0.93      1.00      0.96        54
#           Burns       1.00      1.00      1.00        38
#             Cut       0.90      1.00      0.95        19
# Diabetic Wounds       0.91      0.93      0.92        87
#      Laseration       0.92      0.96      0.94        23
#          Normal       1.00      0.97      0.99        40
# Pressure Wounds       0.94      0.96      0.95       105
# Surgical Wounds       0.99      0.83      0.90        94
#   Venous Wounds       0.89      0.95      0.92        98
#
#        accuracy                           0.94       588
#       macro avg       0.95      0.95      0.95       588
#    weighted avg       0.94      0.94      0.94       588

# %%
# Plot confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=label_encoder.classes_, 
            yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Save the model
model.save('wound_Type.h5')
print("Model saved")
# Out:
# Model saved
