jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1096.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1130.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img354.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img911.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img441.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img399.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1054.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img758.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1312.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img730.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1230.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img781.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img442.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1439.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img193.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img571.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img125.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img30.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img642.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1371.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img772.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img19.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1010.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img419.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img486.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img806.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img506.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img90.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1056.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img494.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img402.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img288.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img283.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img654.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1383.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img443.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1249.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img674.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1422.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1087.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img394.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img454.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/gettyimages-157508133-612x612.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1246.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img316.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1291.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img541.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img180.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1346.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img786.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img38.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img546.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img415.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1028.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img389.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img808.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/gettyimages-114329113-612x612.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img198.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img934.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1396.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img448.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img850.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1380.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img73.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img947.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img554.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img56.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img750.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img114.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img230.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img13.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img968.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img106.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img368.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img25.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img703.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img386.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img391.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1379.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img444.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1440.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1074.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img76.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img588.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img769.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img276.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img397.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img456.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img309.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img596.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img604.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img708.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img650.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img488.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img462.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img429.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img562.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img306.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img380.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img515.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1092.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img469.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img556.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img208.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1051.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img592.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img497.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img355.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img655.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img531.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1344.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img425.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1009.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img986.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1233.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1001.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img937.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1195.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img207.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img570.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img879.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img346.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img116.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img439.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1202.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img74.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img778.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img298.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img284.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img196.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img529.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img450.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img859.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img110.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img696.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img908.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img478.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img158.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1044.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img366.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img352.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1182.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img417.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img330.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img322.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img41.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1395.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img818.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img969.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img695.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img169.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1238.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1035.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img373.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img601.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img307.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1025.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img928.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img438.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img633.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img584.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img470.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img464.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img20.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img68.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img408.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img555.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img256.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img182.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img767.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1133.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img572.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img325.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1193.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img257.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img561.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img156.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1220.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img693.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img738.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img228.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1156.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img492.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1120.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img72.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1266.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img392.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img637.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1101.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img839.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1117.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1014.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img430.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1045.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img223.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img104.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img63.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img595.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1076.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img682.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img249.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img62.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img53.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img1115.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img675.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img157.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img602.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img179.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img569.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img548.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img358.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img665.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img626.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img94.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img992.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img532.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img594.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img828.jpg
# /kaggle/input/burn-dataset13/last_databurn/1st degree/img775.jpg

# %%
from numpy.random import seed
seed(101)
import tensorflow
tensorflow.random.set_seed(101)
import pandas as pd
import numpy as np
import tensorflow
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import os
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.utils import shuffle
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
import itertools
import shutil
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os

# Define the base directory
base_dir = r'/kaggle/working/collect_data_withaug'

# Check if the base directory exists before creating it
if not os.path.exists(base_dir):
    os.mkdir(base_dir)
    print(f"Directory {base_dir} created.")
else:
    print(f"Directory {base_dir} already exists.")

# Define subdirectory paths
degree1 = os.path.join(base_dir, '1')
degree2 = os.path.join(base_dir, '2')
degree3 = os.path.join(base_dir, '3')

# Check if subdirectories exist before creating them
for sub_dir in [degree1, degree2, degree3]:
    if not os.path.exists(sub_dir):
        os.mkdir(sub_dir)
        print(f"Directory {sub_dir} created.")
    else:
        print(f"Directory {sub_dir} already exists.")
# Out:
# Directory /kaggle/working/collect_data_withaug created.
# Directory /kaggle/working/collect_data_withaug/1 created.
# Directory /kaggle/working/collect_data_withaug/2 created.
# Directory /kaggle/working/collect_data_withaug/3 created.

# %%
# addation image in new folders
import cv2
import os
def copy_image(input_file_path, output_file_path):
    image = cv2.imread(input_file_path)
    cv2.imwrite(output_file_path, image)

input_folder_path1 = '/kaggle/input/burn-dataset13/last_databurn/1st degree'
output_folder_path1 = '/kaggle/working/collect_data_withaug/1'
input_folder_path2 = '/kaggle/input/burn-dataset13/last_databurn/2nd degree'
output_folder_path2 = '/kaggle/working/collect_data_withaug/2'
input_folder_path3 = '/kaggle/input/burn-dataset13/last_databurn/3nd degree'
output_folder_path3 = '/kaggle/working/collect_data_withaug/3'
file_list1 = os.listdir(input_folder_path1)
file_list2 = os.listdir(input_folder_path2)
file_list3 = os.listdir(input_folder_path3)
input_file_paths1 = [os.path.join(input_folder_path1, file_name) for file_name in file_list1]
output_file_paths1 = [os.path.join(output_folder_path1, file_name) for file_name in file_list1]
input_file_paths2 = [os.path.join(input_folder_path2, file_name) for file_name in file_list2]
output_file_paths2 = [os.path.join(output_folder_path2, file_name) for file_name in file_list2]
input_file_paths3 = [os.path.join(input_folder_path3, file_name) for file_name in file_list3]
output_file_paths3 = [os.path.join(output_folder_path3, file_name) for file_name in file_list3]
for input_path1, output_path1 in zip(input_file_paths1, output_file_paths1):
    copy_image(input_path1, output_path1)
for input_path2, output_path2 in zip(input_file_paths2, output_file_paths2):
    copy_image(input_path2, output_path2)
for input_path3, output_path3 in zip(input_file_paths3, output_file_paths3):
    copy_image(input_path3, output_path3)

# %%
folder_path = '/kaggle/working/collect_data_withaug/1'
extension = 'jpg'
photo_count = sum(1 for file in os.listdir(folder_path) if file.lower().endswith(f".{extension}"))
print(f'The number of {extension} files in the 1st Degree folder is: {photo_count}')
folder_path = '/kaggle/working/collect_data_withaug/2'
extension = 'jpg'
photo_count = sum(1 for file in os.listdir(folder_path) if file.lower().endswith(f".{extension}"))
print(f'The number of {extension} files in the 2nd Degree folder is: {photo_count}')
folder_path = '/kaggle/working/collect_data_withaug/3'
extension = 'jpg'
photo_count = sum(1 for file in os.listdir(folder_path) if file.lower().endswith(f".{extension}"))
print(f'The number of {extension} files in the 3 folder is: {photo_count}')
# Out:
# The number of jpg files in the 1st Degree folder is: 543
# The number of jpg files in the 2nd Degree folder is: 487
# The number of jpg files in the 3 folder is: 326

# %%
folder_paths1 = [
    '/kaggle/input/burn-dataset13/last_databurn/1st degree',
    '/kaggle/input/burn-dataset13/last_databurn/2nd degree',
    '/kaggle/input/burn-dataset13/last_databurn/3nd degree'
]

extension = 'jpg'
photo_counts = []

for folder_path in folder_paths1:
    photo_count = sum(1 for filename in os.listdir(folder_path)
                      if filename.lower().endswith(f".{extension}"))
    photo_counts.append(photo_count)

# Create class labels based on folder names
class_label = [os.path.basename(path) for path in folder_paths1]

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(photo_counts, labels=class_label, autopct="%1.1f%%", startangle=120)
plt.title("Number of Images per Burn Degree before augmentation", fontsize=12)

plt.axis('equal')
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.show()

# %%
import os
import cv2
from keras.preprocessing.image import ImageDataGenerator
def augment_images(input_directory, output_directory, augmentation_factor):
    # Ensure the output directory exists
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    # Initialize the ImageDataGenerator with desired augmentations
    datagen = ImageDataGenerator(
        zoom_range=0.1,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=True,
    )
    # Load and augment the original images
    image_files = os.listdir(input_directory)
    def load_and_preprocess_image(image_path):
        # Load the image from the specified path
        img = cv2.imread(image_path)
        # You can add any preprocessing steps here as needed
        # For example, resizing the image to a specific size
        img = cv2.resize(img, (224, 224))  # Replace target_width and target_height
        return img
    for image_file in image_files:
        image_path = os.path.join(input_directory, image_file)
        img = load_and_preprocess_image(image_path)  # Load and preprocess your image as needed
        # Reshape to (1, height, width, channels) for the generator
        img = img.reshape((1,) + img.shape)
        i = 0
        for batch in datagen.flow(img, batch_size=1):
            augmented_image = batch[0].astype('uint8')
            augmented_filename = f"{os.path.splitext(image_file)[0]}_augmented_{i}.jpg"
            augmented_image_path = os.path.join(output_directory, augmented_filename)
            cv2.imwrite(augmented_image_path, augmented_image)
            i += 1
            if i >= augmentation_factor:
                break
# Example usage:
input_directory = '/kaggle/input/burn-dataset13/last_databurn/1st degree'
output_directory = '/kaggle/working/collect_data_withaug/1'
augmentation_factor = 5
augment_images(input_directory, output_directory, augmentation_factor)
input_directory = '/kaggle/input/burn-dataset13/last_databurn/2nd degree'
output_directory = '/kaggle/working/collect_data_withaug/2'
augmentation_factor = 5
augment_images(input_directory, output_directory, augmentation_factor)
input_directory = '/kaggle/input/burn-dataset13/last_databurn/3nd degree'
output_directory = '/kaggle/working/collect_data_withaug/3'
augmentation_factor = 6
augment_images(input_directory, output_directory, augmentation_factor)

# %%
folder_path = '/kaggle/working/collect_data_withaug/1'
extension = 'jpg'
photo_count = sum(1 for file in os.listdir(folder_path) if file.lower().endswith(f".{extension}"))
print(f'The number of {extension} files in the 1st Degree folder is: {photo_count}')
folder_path = '/kaggle/working/collect_data_withaug/2'
extension = 'jpg'
photo_count = sum(1 for file in os.listdir(folder_path) if file.lower().endswith(f".{extension}"))
print(f'The number of {extension} files in the 2nd Degree folder is: {photo_count}')
folder_path = '/kaggle/working/collect_data_withaug/3'
extension = 'jpg'
photo_count = sum(1 for file in os.listdir(folder_path) if file.lower().endswith(f".{extension}"))
print(f'The number of {extension} files in the 3rd Degree folder is: {photo_count}')
# Out:
# The number of jpg files in the 1st Degree folder is: 3258
# The number of jpg files in the 2nd Degree folder is: 2927
# The number of jpg files in the 3rd Degree folder is: 2282

# %%
folder_paths = [
    '/kaggle/working/collect_data_withaug/1',
    '/kaggle/working/collect_data_withaug/2',
    '/kaggle/working/collect_data_withaug/3'
]

extension = 'jpg'
photo_counts = []
for folder_path in folder_paths:
    photo_count = sum(1 for filename in os.listdir(folder_path)
                      if filename.lower().endswith(f".{extension}"))
    photo_counts.append(photo_count)

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(photo_counts, labels=class_label, autopct="%1.1f%%", startangle=120)
plt.title("Number of Images per Burn Degree after augmentation", fontsize=12)

plt.axis('equal')
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
labels = ['1','2','3']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/kaggle/working/collect_data_withaug',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 3258/3258 [00:02<00:00, 1151.24it/s]
# 100%|██████████| 2928/2928 [00:03<00:00, 797.56it/s]
# 100%|██████████| 2282/2282 [00:02<00:00, 1095.70it/s]

# %%
import random

k = 0
fig, ax = plt.subplots(1, 3, figsize=(20, 20))
fig.text(s='Sample Image From Each Label', size=18, fontweight='bold',
         fontname='monospace', y=0.62, x=0.4, alpha=0.8)

for i in labels:
    label_indices = [j for j in range(len(y_train)) if y_train[j] == i]
    random_index = random.choice(label_indices)

    ax[k].imshow(X_train[random_index])
    ax[k].set_title(y_train[random_index])
    ax[k].axis('off')
    k += 1

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.2,random_state=101)

# %%
X_train_scaled=X_train/255

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(3,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

EPOCHS = 65
BATCH_SIZE = 32
best_model_dir = '/kaggle/working/'

os.makedirs(best_model_dir, exist_ok=True)

model_checkpoint = ModelCheckpoint(
    os.path.join(best_model_dir, 'best_model.h5'),  # ✅ هنا التغيير
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[model_checkpoint, early_stopping]
)
# Out:
# Epoch 1/65
# 212/212 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.8998
# Epoch 1: val_loss improved from inf to 0.41919, saving model to /kaggle/working/best_model.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 212/212 [==============================] - 59s 280ms/step - loss: 0.2630 - accuracy: 0.8998 - val_loss: 0.4192 - val_accuracy: 0.8636
# Epoch 2/65
# 212/212 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.9133
# Epoch 2: val_loss improved from 0.41919 to 0.29730, saving model to /kaggle/working/best_model.h5
# 212/212 [==============================] - 59s 278ms/step - loss: 0.2440 - accuracy: 0.9133 - val_loss: 0.2973 - val_accuracy: 0.8914
# Epoch 3/65
# 212/212 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9371
# Epoch 3: val_loss did not improve from 0.29730
# 212/212 [==============================] - 59s 277ms/step - loss: 0.1632 - accuracy: 0.9371 - val_loss: 0.3182 - val_accuracy: 0.8955
# Epoch 4/65
# 212/212 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9452
# Epoch 4: val_loss did not improve from 0.29730
# 212/212 [==============================] - 59s 276ms/step - loss: 0.1518 - accuracy: 0.9452 - val_loss: 0.3248 - val_accuracy: 0.8937
# Epoch 5/65
# 212/212 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9551
# Epoch 5: val_loss did not improve from 0.29730
# 212/212 [==============================] - 59s 276ms/step - loss: 0.1245 - accuracy: 0.9551 - val_loss: 0.3609 - val_accuracy: 0.9038
# Epoch 6/65
# 212/212 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9627
# Epoch 6: val_loss improved from 0.29730 to 0.15882, saving model to /kaggle/working/best_model.h5
# 212/212 [==============================] - 59s 280ms/step - loss: 0.1054 - accuracy: 0.9627 - val_loss: 0.1588 - val_accuracy: 0.9421
# Epoch 7/65
# 212/212 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9522
# Epoch 7: val_loss did not improve from 0.15882
# 212/212 [==============================] - 59s 277ms/step - loss: 0.1363 - accuracy: 0.9522 - val_loss: 0.2356 - val_accuracy: 0.9132
# Epoch 8/65
# 212/212 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9634
# Epoch 8: val_loss improved from 0.15882 to 0.11673, saving model to /kaggle/working/best_model.h5
# 212/212 [==============================] - 59s 280ms/step - loss: 0.0971 - accuracy: 0.9634 - val_loss: 0.1167 - val_accuracy: 0.9575
# Epoch 9/65
# 212/212 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9684
# Epoch 9: val_loss did not improve from 0.11673
# 212/212 [==============================] - 58s 276ms/step - loss: 0.0887 - accuracy: 0.9684 - val_loss: 0.1811 - val_accuracy: 0.9368
# Epoch 10/65
# 212/212 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9681
# Epoch 10: val_loss did not improve from 0.11673
# 212/212 [==============================] - 59s 276ms/step - loss: 0.0895 - accuracy: 0.9681 - val_loss: 0.2649 - val_accuracy: 0.9203
# Epoch 11/65
# 212/212 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9725
# Epoch 11: val_loss did not improve from 0.11673
# 212/212 [==============================] - 59s 276ms/step - loss: 0.0735 - accuracy: 0.9725 - val_loss: 0.2436 - val_accuracy: 0.9286
# Epoch 12/65
# 212/212 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9675
# Epoch 12: val_loss did not improve from 0.11673
# 212/212 [==============================] - 59s 278ms/step - loss: 0.0909 - accuracy: 0.9675 - val_loss: 0.2170 - val_accuracy: 0.9392
# Epoch 13/65
# 212/212 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9739
# Epoch 13: val_loss did not improve from 0.11673
# 212/212 [==============================] - 59s 277ms/step - loss: 0.0644 - accuracy: 0.9739 - val_loss: 0.1750 - val_accuracy: 0.9486

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the variable holding the training history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plotting training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save('/kaggle/working/Burn.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
y_pred=model.predict(X_test)
print(y_pred)
import numpy as np
z=np.argmax(y_pred, axis=1) #return index of the large number
z
# Out:
# 53/53 [==============================] - 4s 58ms/step
# [[2.0753025e-05 9.9997926e-01 4.1070514e-10]
#  [2.1050323e-16 7.8506748e-09 1.0000000e+00]
#  [9.9986124e-01 1.3821908e-04 4.5042177e-07]
#  ...
#  [9.9251819e-01 1.3363702e-04 7.3481901e-03]
#  [9.9987817e-01 1.2178099e-04 4.8006523e-09]
#  [1.4981219e-03 9.6152739e-08 9.9850178e-01]]
# array([1, 2, 0, ..., 0, 0, 2])

# %%
y_test_ = np.argmax(y_test, axis=1)

print(y_test_)
# Out:
# [1 2 0 ... 0 0 2]

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_, z))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       672
#            1       0.96      0.90      0.93       557
#            2       0.94      0.97      0.95       465
#
#     accuracy                           0.95      1694
#    macro avg       0.95      0.95      0.95      1694
# weighted avg       0.95      0.95      0.95      1694

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate confusion matrix
conf_mat = confusion_matrix(y_test_, z)
print(conf_mat)
# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0', 'Class 1', 'Class 2'],
            yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[651  14   7]
#  [ 30 504  23]
#  [  6   7 452]]

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np

# Load EfficientNetB0 for feature extraction (exclude the top fully connected layer)
base_model = EfficientNetB0(include_top=False, pooling='avg')

# Function to preprocess the input image and resize it to 224x224 (required for EfficientNetB0)
def preprocess_image(img_path):
    img = load_img(img_path, target_size=(224, 224))  # EfficientNetB0 expects 224x224 images
    img_array = img_to_array(img) / 255.0  # Normalize image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Function to extract features using EfficientNetB0
def extract_features(img_array):
    features = base_model.predict(img_array)
    print(f"Extracted features shape: {features.shape}")  # Debugging output
    return features

# Example image path for testing
img_path = '/kaggle/input/burn-dataset13/last_databurn/3nd degree/google_0238.jpg'

# Preprocess and extract features
img_array = preprocess_image(img_path)
features = extract_features(img_array)
# Out:
# 1/1 [==============================] - 2s 2s/step
# Extracted features shape: (1, 1280)

# %%
print(f"Shape of X_train_scaled: {X_train_scaled.shape}")
print(f"Type of X_train_scaled: {type(X_train_scaled)}")
# Out:
# Shape of X_train_scaled: (6774, 224, 224, 3)
# Type of X_train_scaled: <class 'numpy.ndarray'>
